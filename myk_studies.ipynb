# %% [markdown]
# Generate a studies table from scratch (without autoreading in any data)

# %%
import numpy as np
import pandas as pd

# %%
studies = [['myk_461_004','Pioneer HCM',2,[],'Obstructive HCM','Open-label Pilot Study to Evaluate Efficacy, Pharmacokinetics, Pharmacodynamics, Safety, and Tolerability of MYK-461 in Subjects With Symptomatic Hypertrophic Cardiomyopathy and Left Ventricular Outflow Tract Obstruction'.lower(),0],
           ['myk_461_005','Explorer',3,[],'HCM','Randomized, Double-blind, Placebo-controlledClinical Study to Evaluate Mavacamten (MYK-461) in Adults with Symptomatic Obstructive Hypertrophic Cardiomyopathy'.lower(),0],
           ['myk_461_006','Maverick',2,[],"HCM",'Double-blind',0],
           ['myk_461_007','MAVA-LTE',3,['myk_461_005','myk_461_006'],'HCM','Double-blind, LONG-TERM SAFETY EXTENSION STUDY OF MAVACAMTEN (MYK-461) IN ADULTS WITH HYPERTROPHIC CARDIOMYOPATHY WHO HAVE COMPLETED THE MAVERICK-HCM (MYK-461-006) OR EXPLORER-HCM (MYK-461-005) TRIALS (MAVA-LTE)'.lower(),1],
           ['myk_461_008','Pioneer-OLE',2,['myk_461_004'],'HCM','Open-label Extension Study of Mavacamten (MYK-461) in Adults with Symptomatic Obstructive Hypertrophic CardiomyopathyPreviously Enrolled in Study MYK-461-004 (PIONEER-HCM)'.lower(),0],
           ['myk_461_012','CYP2C219',1,[],'HCM','Open-label Study of the Pharmacokinetics of Single-Dose Mavacamten in Healthy Adults Who Are Normal or Poor CYP 2C19 Metabolizers Based on Genotype'.lower(),0],
           ['myk_461_013','ADME',1,[],'HCM','Open-label, Single Dose, Mass-Balance Study to Assess the Absorption, Metabolism, and Excretion of [14C]-Mavacamten in Healthy Males'.lower(),0],
           ['myk_461_014','Food EF+BioA',1,[],'HCM','Open-label, Relative Bioavailability of the Intended Commercial Capsule Formulation vs. the Initial Capsule Formulation of Mavacamten and the Effect of Food on its Pharmacokinetics'.lower(),0],
           ['myk_461_015','Hep Impairment',1,[],'HCM','Open-Label, Non-Randomized, Single-Dose Study to Investigate the Pharmacokinetics, Safety, and Tolerability of Mavacamten in Participants with Varying Degrees of Hepatic Impairment Compared to Participants with Normal Hepatic Function'.lower(),1],
           ['myk_461_016','CYP 3A4 Inducer',1,[],'HCM','Effect of Mavacamten on the Pharmacokinetics of the CYP3A4 Substrate, Midazolam, in Healthy Participants'.lower(),1],
           ['myk_461_017','Valor-HCM SRT',3,[],'HCM','RANDOMIZED, DOUBLE-BLIND, PLACEBO-CONTROLLED STUDY TO EVALUATE MAVACAMTEN IN ADULTS WITH SYMPTOMATIC OBSTRUCTIVE HYPERTROPHIC CARDIOMYOPATHY WHO ARE ELIGIBLE FOR SEPTAL REDUCTION THERAPY'.lower(),1],
           ['myk_461_018','Omeprazole',1,[],'HCM','Open-label Drug Interaction study to Assess the Effect of the Proton Pump Inhibitor Omeprazole, a CYP2C19 inhibitor, on Mavacamten (MYK-461) Pharmacokinetics in Healthy Participants'.lower(),1],
           ['myk_461_019','HFpEF POC',2,[],'HCM','Exploratory, Open-Label, Proof-of-Concept Study of Mavacamten (MYK-461) in Patients with Heart Failure with Preserved Ejection Fraction (HFpEF) and Chronic Elevation of Cardiac Troponin-I and/or NT-proBNP'.lower(),1],
           ['myk_224_001','HV SAD/MAD',1,[],'HCM','Double-BLIND, RANDOMIZED, PLACEBO-CONTROLLED, NESTED ASCENDING SINGLE ORAL DOSE (WITH FOOD STUDY) AND ASCENDING MULTIPLE ORAL DOSE STUDY TO EVALUATE SAFETY, TOLERABILITY, PHARMACOKINETICS AND PHARMACODYNAMICS OF MYK-224 IN HEALTHY VOLUNTEERS'.lower(),1],
           ['myk_491_003','HF-SAD/MAD',1,[],'Heart Failure with Reduced Ejection Fraction','Randomized, Double-blind, Crossover, Placebo-controlled, Adaptive Design Study of Safety, Tolerability, Preliminary Pharmacokinetics, and Pharmacodynamics of SingleAscending Oral Doses of MYK-491 in Patients with Stable Heart Failure'.lower(),1],
           ['myk_491_006','',2,[],'Primary Dilated Cardiomyopathy due to MYH7 Mutation','Open-Label Exploratory Study of Oral MYK-491 in Stable Ambulatory Patients with Primary Dilated Cardiomyopathy due to MYH7 Mutation'.lower(),1],
           ['myk_491_201','',0,[],'','',1]]

# %%
STUDIES = pd.DataFrame(studies, columns=['study_id','study_name','phase','parent_study','indication','study_description','active'])

# %%
STUDIES.to_csv('C:/Users/dgao/Desktop/Spotfire_DATA/all_studies.csv')

# %%
STUDIES
# Out:
#        study_id       study_name  phase                parent_study  \
# 0   myk_461_004      Pioneer HCM      2                          []
# 1   myk_461_005         Explorer      3                          []
# 2   myk_461_006         Maverick      2                          []
# 3   myk_461_007         MAVA-LTE      3  [myk_461_005, myk_461_006]
# 4   myk_461_008      Pioneer-OLE      2               [myk_461_004]
# 5   myk_461_012         CYP2C219      1                          []
# 6   myk_461_013             ADME      1                          []
# 7   myk_461_014     Food EF+BioA      1                          []
# 8   myk_461_015   Hep Impairment      1                          []
# 9   myk_461_016  CYP 3A4 Inducer      1                          []
# 10  myk_461_017    Valor-HCM SRT      3                          []
# 11  myk_461_018       Omeprazole      1                          []
# 12  myk_461_019        HFpEF POC      2                          []
# ...
